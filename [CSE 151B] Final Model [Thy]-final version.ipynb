# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np

import os

from datetime import datetime
import time

import seaborn as sns
import matplotlib.pyplot as plt

import statistics
import random

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings('ignore')

# %%
if os.path.exists('dftrain.csv'):
    dftrain = pd.read_csv('dftrain.csv')
if os.path.exists('dftest.csv'):
    dftest = pd.read_csv('dftest.csv')

# %%
df = pd.read_csv('train_cleaned.csv')

# %% [markdown]
# # LDA
# ### Upperbound = median

# %%
def lda_complete(taxi_id, is_cut=True, cutoff=0.5, test_size=0.99):
    newtrain=dftrain[dftrain['TAXI_ID'] == taxi_id]
    
    train_corr=newtrain[['TRAVEL_TIME', 'YEAR', 'MONTH', 'WEEK', 'DAY', 'HOUR', 'MIN', 'WEEKDAY']].corr()
    positive_corr_list=list(train_corr[train_corr > 0]['TRAVEL_TIME'].dropna().keys())
    positive_corr_list.remove('TRAVEL_TIME')
    
    ## outlier cut
    tmpdf = newtrain
    Q1 = tmpdf['TRAVEL_TIME'].quantile(0.25)
    Q2 = tmpdf['TRAVEL_TIME'].max()
    if is_cut:
        Q2 = tmpdf['TRAVEL_TIME'].quantile(cutoff)
    Q3 = tmpdf['TRAVEL_TIME'].quantile(0.75)
    IQR = Q3 - Q1

    # Define the lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q2

    new_train = newtrain[newtrain.TRAVEL_TIME >= lower_bound]
    new_train = newtrain[newtrain.TRAVEL_TIME <= upper_bound]

    print('upper_bound', upper_bound)
    
    avail_times = new_train.TRAVEL_TIME.unique()
    n = len(avail_times)
    range_ = list(range(n))
    labels = dict(zip(avail_times,range_))
    labels_rev = dict(zip(range_, avail_times))
    
    X = []
    y = []

    for row in new_train.iterrows():

        lst = []
        for elem in positive_corr_list:
            lst.append(row[1][elem])

        X.append(np.array(lst))
        y.append(np.array(labels[row[1]['TRAVEL_TIME']]))
    
    # Split the dataset into training and testing sets
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=test_size, random_state=42)
    
    ytrain = []
    for i in y_train:
        ytrain.append(i.item())
        
    if len(set(ytrain)) >= len(X_train):
        return (None, None)
    
    # Create an LDA classifier
    lda = LinearDiscriminantAnalysis()

    # Fit the LDA model on the training data
    lda.fit(X_train, y_train)

    # Predict the class labels for the test data
    y_pred = lda.predict(X_train)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_train, y_pred)
    print("Training Accuracy:", accuracy)
    
    mse_train = mean_squared_error(y_train, y_pred)
    rmse_train = mse_train**(1/2)    
    print('Training loss: RMSE=', rmse_train)
    
    new_test = dftest[dftest.TAXI_ID == taxi_id]
    
    Xtest = []
    trips = []
    
    for row in new_test.iterrows():
        trips.append(row[1]['TRIP_ID'])
        lst = []
        for elem in positive_corr_list:#, 'WEEKDAY']:
            lst.append(row[1][elem])
        Xtest.append(np.array(lst))
    
    preds = lda.predict(Xtest)
    r = len(preds)
    output = []
    for i in range(r):
        print(trips[i], labels_rev[preds[i]])
        output.append(labels_rev[preds[i]])
    return (trips, output)

# %% [markdown]
# # Try to scale

# %%
taxi_ids=list(dftest.TAXI_ID)

# %%
# %%time

### Round 1 ###
all_trips = []
all_preds = []
not_ok = []
for taxi_id in taxi_ids:
    if taxi_id in [20000079, 20000206]:
        continue
    print('----------------------')
    print(taxi_id)
    trips, output = lda_complete(taxi_id=taxi_id, is_cut=True, cutoff=0.5)
    if output is None:
        not_ok.append(taxi_id)
    else:
        r = len(trips)

        for i in range(r):
            all_trips.append(trips[i])
            all_preds.append(output[i])
            
            
### Round 2 ###
not_ok_2 = []
for taxi_id in not_ok:
#     if taxi_id in [20000079, 20000206]:
#         continue
    print('----------------------')
    print(taxi_id)
    trips, output = lda_complete(taxi_id=taxi_id, is_cut=True, cutoff=0.5, test_size=0.98)
    if output is None:
        not_ok_2.append(taxi_id)
    else:
        r = len(trips)

        for i in range(r):
            all_trips.append(trips[i])
            all_preds.append(output[i])
            
### Round 3 ###
weird = [20000079, 20000206]
for taxi_id in weird:
    print('----------------------')
    print(taxi_id)
    trips, output = lda_complete(taxi_id=taxi_id, is_cut=True, cutoff=0.5, test_size=0.5)
    if output is None:
        not_ok_2.append(taxi_id)
    else:
        r = len(trips)

        for i in range(r):
            all_trips.append(trips[i])
            all_preds.append(output[i])
# Out:
# ----------------------
# 20000542
# upper_bound 630.0
# Training Accuracy: 0.43333333333333335
# Training loss: RMSE= 13.745302227791623
# T1 390
# T308 525
# ----------------------
# 20000108
# upper_bound 585.0
# Training Accuracy: 0.3333333333333333
# Training loss: RMSE= 9.735387911006821
# T2 405
# T249 450
# ----------------------
# 20000370
# upper_bound 555.0
# Training Accuracy: 0.75
# Training loss: RMSE= 3.2596012026013246
# T3 510
# ----------------------
# 20000492
# upper_bound 540.0
# Training Accuracy: 0.5277777777777778
# Training loss: RMSE= 7.2264944628929335
# T4 465
# T250 315
# ----------------------
# 20000621
# upper_bound 540.0
# Training Accuracy: 0.6944444444444444
# Training loss: RMSE= 7.820912137766711
# T5 495
# ----------------------
# 20000607
# upper_bound 795.0
# Training Accuracy: 0.9411764705882353
# Training loss: RMSE= 4.608176875690327
# T6 315
# ----------------------
# 20000310
# upper_bound 585.0
# Training Accuracy: 0.7916666666666666
# Training loss: RMSE= 3.6685601171758564
# T7 300
# ----------------------
# 20000619
# upper_bound 615.0
# Training Accuracy: 0.4666666666666667
# Training loss: RMSE= 8.702490065109718
# T8 450
# ----------------------
# 20000503
# upper_bound 510.0
# Training Accuracy: 0.5333333333333333
# Training loss: RMSE= 8.752142594816426
# T9 255
# T138 315
# T252 240
# ----------------------
# 20000327
# upper_bound 675.0
# Training Accuracy: 0.9285714285714286
# Training loss: RMSE= 7.216053531635458
# T10 510
# ----------------------
# 20000664
# upper_bound 600.0
# Training Accuracy: 0.5652173913043478
# Training loss: RMSE= 11.137480786105517
# T11 525
# T251 390
# ----------------------
# 20000160
# upper_bound 615.0
# Training Accuracy: 0.85
# Training loss: RMSE= 6.652067347825035
# T12 315
# ----------------------
# 20000017
# upper_bound 570.0
# Training Accuracy: 0.38461538461538464
# Training loss: RMSE= 7.253646297923867
# T13 360
# T157 360
# ----------------------
# 20000312
# upper_bound 1005.0
# ----------------------
# 20000497
# upper_bound 615.0
# Training Accuracy: 0.42857142857142855
# Training loss: RMSE= 6.6904338246413255
# T15 450
# ----------------------
# 20000440
# upper_bound 615.0
# Training Accuracy: 0.9473684210526315
# Training loss: RMSE= 2.752988806446741
# T16 330
# T154 300
# ----------------------
# 20000467
# upper_bound 645.0
# Training Accuracy: 0.8888888888888888
# Training loss: RMSE= 3.6666666666666665
# T17 480
# ----------------------
# 20000338
# upper_bound 630.0
# Training Accuracy: 0.8333333333333334
# Training loss: RMSE= 1.20761472884912
# T18 615
# T204 390
# ----------------------
# 20000101
# upper_bound 630.0
# Training Accuracy: 0.7857142857142857
# Training loss: RMSE= 7.316810390170999
# T19 615
# ----------------------
# 20000523
# upper_bound 645.0
# Training Accuracy: 0.5833333333333334
# Training loss: RMSE= 6.652067347825035
# T20 630
# T137 570
# ----------------------
# 20000460
# upper_bound 645.0
# Training Accuracy: 0.6666666666666666
# Training loss: RMSE= 6.928203230275509
# T21 510
# T292 420
# ----------------------
# 20000199
# upper_bound 645.0
# Training Accuracy: 0.9032258064516129
# Training loss: RMSE= 6.140820581921837
# T22 435
# ----------------------
# 20000480
# upper_bound 645.0
# Training Accuracy: 0.8695652173913043
# Training loss: RMSE= 4.938755343993675
# T23 240
# ----------------------
# 20000250
# upper_bound 645.0
# Training Accuracy: 0.4
# Training loss: RMSE= 11.46298390472568
# T24 450
# T184 150
# T295 570
# ----------------------
# 20000903
# upper_bound 645.0
# Training Accuracy: 0.6666666666666666
# Training loss: RMSE= 5.838093296045665
# T25 405
# ----------------------
# 20000247
# upper_bound 615.0
# Training Accuracy: 0.8125
# Training loss: RMSE= 6.041522986797286
# T26 390
# T311 435
# ----------------------
# 20000263
# upper_bound 570.0
# Training Accuracy: 0.34375
# Training loss: RMSE= 9.094984881790623
# T27 570
# T265 495
# ----------------------
# 20000500
# upper_bound 720.0
# Training Accuracy: 0.7692307692307693
# Training loss: RMSE= 4.590961018885161
# T28 570
# ----------------------
# 20000617
# upper_bound 645.0
# Training Accuracy: 0.4074074074074074
# Training loss: RMSE= 15.137640111594282
# T29 645
# T82 300
# ----------------------
# 20000288
# upper_bound 630.0
# Training Accuracy: 0.7368421052631579
# Training loss: RMSE= 7.419746058925964
# T30 270
# ----------------------
# 20000268
# upper_bound 570.0
# Training Accuracy: 0.6521739130434783
# Training loss: RMSE= 7.027894730844087
# T31 525
# ----------------------
# 20000495
# upper_bound 645.0
# Training Accuracy: 0.16666666666666666
# Training loss: RMSE= 15.052685253247454
# T32 420
# ----------------------
# 20000328
# upper_bound 585.0
# Training Accuracy: 0.7666666666666667
# Training loss: RMSE= 4.377975178854566
# T33 0
# ----------------------
# 20000129
# upper_bound 705.0
# Training Accuracy: 0.7692307692307693
# Training loss: RMSE= 6.928203230275509
# T34 0
# T196 645
# T263 630
# ----------------------
# 20000434
# upper_bound 690.0
# Training Accuracy: 0.8636363636363636
# Training loss: RMSE= 8.916277250063503
# T35 465
# T100 405
# T230 615
# T256 525
# ----------------------
# 20000381
# upper_bound 615.0
# Training Accuracy: 0.7619047619047619
# Training loss: RMSE= 4.680252333449758
# T36 30
# T205 420
# ----------------------
# 20000159
# upper_bound 735.0
# Training Accuracy: 0.25
# Training loss: RMSE= 15.253414918196734
# T37 660
# T142 660
# ----------------------
# 20000048
# upper_bound 675.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T38 510
# ----------------------
# 20000008
# upper_bound 585.0
# Training Accuracy: 0.9166666666666666
# Training loss: RMSE= 2.282177322938192
# T39 390
# ----------------------
# 20000285
# upper_bound 600.0
# Training Accuracy: 0.8148148148148148
# Training loss: RMSE= 4.682512779045662
# T40 0
# T254 555
# ----------------------
# 20000546
# upper_bound 615.0
# Training Accuracy: 0.8235294117647058
# Training loss: RMSE= 5.6412347417710516
# T41 300
# ----------------------
# 20000353
# upper_bound 600.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T42 270
# ----------------------
# 20000569
# upper_bound 630.0
# Training Accuracy: 0.9
# Training loss: RMSE= 4.455333881989093
# T43 165
# ----------------------
# 20000384
# upper_bound 570.0
# Training Accuracy: 0.29411764705882354
# Training loss: RMSE= 10.563533276992015
# T44 555
# T131 555
# ----------------------
# 20000653
# upper_bound 600.0
# Training Accuracy: 0.7
# Training loss: RMSE= 7.871890920653478
# T45 465
# T190 465
# ----------------------
# 20000540
# upper_bound 630.0
# Training Accuracy: 0.8571428571428571
# Training loss: RMSE= 5.809475019311125
# T46 0
# T228 225
# ----------------------
# 20000280
# upper_bound 615.0
# Training Accuracy: 0.5714285714285714
# Training loss: RMSE= 6.447590912226719
# T47 285
# ----------------------
# 20000177
# upper_bound 705.0
# Training Accuracy: 0.3076923076923077
# Training loss: RMSE= 11.421976118935744
# T48 600
# ----------------------
# 20000085
# upper_bound 765.0
# Training Accuracy: 0.4
# Training loss: RMSE= 21.120290402043874
# T49 660
# T141 510
# ----------------------
# 20000022
# upper_bound 600.0
# Training Accuracy: 0.65
# Training loss: RMSE= 10.166120203892929
# T50 570
# ----------------------
# 20000311
# upper_bound 750.0
# Training Accuracy: 0.8695652173913043
# Training loss: RMSE= 6.0756105436623296
# T51 465
# T222 465
# ----------------------
# 20000294
# upper_bound 690.0
# Training Accuracy: 0.5
# Training loss: RMSE= 11.086027241532468
# T52 90
# ----------------------
# 20000081
# upper_bound 615.0
# Training Accuracy: 0.52
# Training loss: RMSE= 8.423775875461075
# T53 420
# T242 525
# T307 420
# ----------------------
# 20000561
# upper_bound 630.0
# Training Accuracy: 0.9285714285714286
# Training loss: RMSE= 5.271215636427169
# T54 420
# ----------------------
# 20000178
# upper_bound 630.0
# Training Accuracy: 0.625
# Training loss: RMSE= 6.552671211040578
# T55 510
# ----------------------
# 20000255
# upper_bound 615.0
# Training Accuracy: 0.65
# Training loss: RMSE= 6.859300255857007
# T56 270
# T327 390
# ----------------------
# 20000547
# upper_bound 570.0
# ----------------------
# 20000603
# upper_bound 615.0
# Training Accuracy: 0.7692307692307693
# Training loss: RMSE= 8.602325267042627
# T58 330
# T247 345
# ----------------------
# 20000668
# upper_bound 795.0
# Training Accuracy: 0.5625
# Training loss: RMSE= 6.87386354243376
# T59 690
# T234 675
# ----------------------
# 20000044
# upper_bound 645.0
# Training Accuracy: 0.2
# Training loss: RMSE= 10.83205120618128
# T60 420
# ----------------------
# 20000041
# upper_bound 675.0
# Training Accuracy: 0.85
# Training loss: RMSE= 4.153311931459037
# T61 570
# ----------------------
# 20000245
# upper_bound 585.0
# Training Accuracy: 0.68
# Training loss: RMSE= 9.258509599282165
# T62 240
# T255 480
# ----------------------
# 20000649
# upper_bound 555.0
# Training Accuracy: 0.7142857142857143
# Training loss: RMSE= 7.131419413913534
# T63 180
# T169 180
# ----------------------
# 20000662
# upper_bound 660.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T64 285
# ----------------------
# 20000055
# upper_bound 555.0
# Training Accuracy: 0.9090909090909091
# Training loss: RMSE= 0.9045340337332909
# T65 240
# ----------------------
# 20000595
# upper_bound 630.0
# Training Accuracy: 0.21739130434782608
# Training loss: RMSE= 8.392543274162824
# T66 600
# ----------------------
# 20000140
# upper_bound 600.0
# Training Accuracy: 0.5806451612903226
# Training loss: RMSE= 9.250980767534344
# T67 510
# ----------------------
# 20000260
# upper_bound 495.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T68 210
# T128 495
# ----------------------
# 20000576
# upper_bound 705.0
# Training Accuracy: 0.8888888888888888
# Training loss: RMSE= 3.9510898637098992
# T69 450
# ----------------------
# 20000047
# upper_bound 555.0
# Training Accuracy: 0.8181818181818182
# Training loss: RMSE= 6.007570980929738
# T70 465
# T306 285
# ----------------------
# 20000010
# upper_bound 585.0
# Training Accuracy: 0.6551724137931034
# Training loss: RMSE= 9.09717652294684
# T71 420
# T77 420
# ----------------------
# 20000004
# upper_bound 675.0
# Training Accuracy: 0.8
# Training loss: RMSE= 3.40587727318528
# T72 390
# ----------------------
# 20000334
# upper_bound 630.0
# Training Accuracy: 0.9411764705882353
# Training loss: RMSE= 6.5484618759809905
# T73 270
# T227 360
# T288 570
# ----------------------
# 20000256
# upper_bound 630.0
# Training Accuracy: 0.6666666666666666
# Training loss: RMSE= 7.5249584716462055
# T74 300
# T253 300
# ----------------------
# 20000349
# upper_bound 660.0
# Training Accuracy: 0.8235294117647058
# Training loss: RMSE= 7.328429733097069
# T75 615
# T194 420
# ----------------------
# 20000675
# upper_bound 600.0
# Training Accuracy: 0.8214285714285714
# Training loss: RMSE= 6.425396041156863
# T76 225
# ----------------------
# 20000010
# upper_bound 585.0
# Training Accuracy: 0.6551724137931034
# Training loss: RMSE= 9.09717652294684
# T71 420
# T77 420
# ----------------------
# 20000224
# upper_bound 630.0
# Training Accuracy: 0.9047619047619048
# Training loss: RMSE= 3.2805342189809212
# T78 300
# ----------------------
# 20000901
# upper_bound 615.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T79 315
# ----------------------
# 20000488
# upper_bound 660.0
# Training Accuracy: 0.5652173913043478
# Training loss: RMSE= 10.603526894797582
# T80 255
# T176 555
# ----------------------
# 20000633
# upper_bound 615.0
# Training Accuracy: 0.34615384615384615
# Training loss: RMSE= 10.243196616441418
# T81 420
# ----------------------
# 20000617
# upper_bound 645.0
# Training Accuracy: 0.4074074074074074
# Training loss: RMSE= 15.137640111594282
# T29 645
# T82 300
# ----------------------
# 20000188
# upper_bound 675.0
# Training Accuracy: 0.9523809523809523
# Training loss: RMSE= 2.1821789023599236
# T83 510
# ----------------------
# 20000436
# upper_bound 690.0
# Training Accuracy: 0.5555555555555556
# Training loss: RMSE= 10.438532605829373
# T84 450
# T188 390
# T317 390
# ----------------------
# 20000578
# upper_bound 615.0
# Training Accuracy: 0.8125
# Training loss: RMSE= 4.860555523805895
# T85 600
# ----------------------
# 20000116
# upper_bound 615.0
# Training Accuracy: 0.6521739130434783
# Training loss: RMSE= 8.861249298515125
# T86 360
# ----------------------
# 20000477
# upper_bound 735.0
# Training Accuracy: 0.6363636363636364
# Training loss: RMSE= 6.888725967444594
# T87 720
# ----------------------
# 20000624
# upper_bound 600.0
# Training Accuracy: 0.7241379310344828
# Training loss: RMSE= 7.339078209524493
# T88 360
# T174 0
# ----------------------
# 20000572
# upper_bound 600.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T90 255
# ----------------------
# 20000249
# upper_bound 630.0
# Training Accuracy: 0.25806451612903225
# Training loss: RMSE= 14.771375981508857
# T91 255
# T162 330
# ----------------------
# 20000612
# upper_bound 615.0
# Training Accuracy: 0.6538461538461539
# Training loss: RMSE= 5.262348115842175
# T92 435
# T225 435
# T304 435
# ----------------------
# 20000560
# upper_bound 555.0
# Training Accuracy: 0.5357142857142857
# Training loss: RMSE= 7.768985960673558
# T93 555
# T272 345
# ----------------------
# 20000372
# upper_bound 615.0
# Training Accuracy: 0.15151515151515152
# Training loss: RMSE= 7.397788367294155
# T94 585
# ----------------------
# 20000071
# upper_bound 615.0
# ----------------------
# 20000688
# upper_bound 570.0
# Training Accuracy: 0.3103448275862069
# Training loss: RMSE= 8.76119972889873
# T96 330
# ----------------------
# 20000904
# upper_bound 1005.0
# Training Accuracy: 0.96
# Training loss: RMSE= 3.4
# T98 840
# ----------------------
# 20000060
# upper_bound 600.0
# Training Accuracy: 0.4230769230769231
# Training loss: RMSE= 18.558638875819447
# T99 360
# ----------------------
# 20000434
# upper_bound 690.0
# Training Accuracy: 0.8636363636363636
# Training loss: RMSE= 8.916277250063503
# T35 465
# T100 405
# T230 615
# T256 525
# ----------------------
# 20000112
# upper_bound 645.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T101 255
# T239 510
# ----------------------
# 20000286
# upper_bound 435.0
# Training Accuracy: 0.8571428571428571
# Training loss: RMSE= 4.59813626840888
# T102 300
# ----------------------
# 20000036
# upper_bound 720.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T103 375
# ----------------------
# 20000086
# upper_bound 615.0
# Training Accuracy: 0.9375
# Training loss: RMSE= 1.5
# T104 480
# ----------------------
# 20000574
# upper_bound 615.0
# Training Accuracy: 0.7666666666666667
# Training loss: RMSE= 5.344779384283945
# T107 540
# T202 420
# ----------------------
# 20000331
# upper_bound 570.0
# Training Accuracy: 0.7647058823529411
# Training loss: RMSE= 6.606592073340794
# T109 465
# ----------------------
# 20000026
# upper_bound 555.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T110 180
# T245 555
# ----------------------
# 20000518
# upper_bound 615.0
# Training Accuracy: 0.9565217391304348
# Training loss: RMSE= 1.4596008983995234
# T111 345
# ----------------------
# 20000541
# upper_bound 660.0
# Training Accuracy: 0.55
# Training loss: RMSE= 7.317786550590281
# T112 660
# ----------------------
# 20000400
# upper_bound 525.0
# Training Accuracy: 0.8823529411764706
# Training loss: RMSE= 1.9553847221876073
# T113 165
# ----------------------
# 20000682
# upper_bound 705.0
# ----------------------
# 20000039
# upper_bound 660.0
# Training Accuracy: 0.21052631578947367
# Training loss: RMSE= 16.888177116426434
# T115 600
# ----------------------
# 20000597
# upper_bound 645.0
# Training Accuracy: 0.4375
# Training loss: RMSE= 11.736694594305503
# T116 585
# ----------------------
# 20000230
# upper_bound 660.0
# Training Accuracy: 0.9230769230769231
# Training loss: RMSE= 6.933752452815364
# T117 285
# ----------------------
# 20000126
# upper_bound 540.0
# Training Accuracy: 0.8666666666666667
# Training loss: RMSE= 4.016632088371218
# T119 330
# ----------------------
# 20000296
# upper_bound 705.0
# Training Accuracy: 0.4166666666666667
# Training loss: RMSE= 10.677078252031311
# T120 225
# ----------------------
# 20000049
# upper_bound 705.0
# ----------------------
# 20000383
# upper_bound 645.0
# Training Accuracy: 0.7333333333333333
# Training loss: RMSE= 6.137317546507322
# T122 495
# T313 630
# ----------------------
# 20000156
# upper_bound 690.0
# Training Accuracy: 0.8
# Training loss: RMSE= 7.602631123499285
# T123 690
# ----------------------
# 20000198
# upper_bound 585.0
# Training Accuracy: 0.7333333333333333
# Training loss: RMSE= 4.273952113286562
# T124 285
# ----------------------
# 20000596
# upper_bound 645.0
# Training Accuracy: 0.45
# Training loss: RMSE= 16.127616066858735
# T125 300
# T201 300
# ----------------------
# 20000248
# upper_bound 600.0
# ----------------------
# 20000591
# upper_bound 585.0
# Training Accuracy: 0.5416666666666666
# Training loss: RMSE= 8.374067112222113
# T127 375
# T210 405
# ----------------------
# 20000260
# upper_bound 495.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T68 210
# T128 495
# ----------------------
# 20000005
# upper_bound 555.0
# Training Accuracy: 0.7666666666666667
# Training loss: RMSE= 4.58257569495584
# T129 240
# T276 420
# ----------------------
# 20000686
# upper_bound 540.0
# Training Accuracy: 0.3548387096774194
# Training loss: RMSE= 10.030598348344252
# T130 315
# T274 345
# ----------------------
# 20000384
# upper_bound 570.0
# Training Accuracy: 0.29411764705882354
# Training loss: RMSE= 10.563533276992015
# T44 555
# T131 555
# ----------------------
# 20000272
# upper_bound 585.0
# Training Accuracy: 0.8
# Training loss: RMSE= 10.564090116995406
# T132 525
# ----------------------
# 20000314
# upper_bound 660.0
# Training Accuracy: 0.2
# Training loss: RMSE= 10.905656024895217
# T133 240
# ----------------------
# 20000625
# upper_bound 600.0
# Training Accuracy: 0.6333333333333333
# Training loss: RMSE= 9.520154060378085
# T134 420
# ----------------------
# 20000589
# upper_bound 615.0
# Training Accuracy: 0.625
# Training loss: RMSE= 10.752906583803284
# T135 465
# ----------------------
# 20000476
# upper_bound 465.0
# Training Accuracy: 0.4838709677419355
# Training loss: RMSE= 6.458302982932501
# T136 390
# T281 270
# ----------------------
# 20000523
# upper_bound 645.0
# Training Accuracy: 0.5833333333333334
# Training loss: RMSE= 6.652067347825035
# T20 630
# T137 570
# ----------------------
# 20000503
# upper_bound 510.0
# Training Accuracy: 0.5333333333333333
# Training loss: RMSE= 8.752142594816426
# T9 255
# T138 315
# T252 240
# ----------------------
# 20000473
# upper_bound 615.0
# Training Accuracy: 0.2
# Training loss: RMSE= 9.423375191511797
# T139 255
# ----------------------
# 20000092
# upper_bound 570.0
# Training Accuracy: 0.55
# Training loss: RMSE= 9.281702430050212
# T140 300
# ----------------------
# 20000085
# upper_bound 765.0
# Training Accuracy: 0.4
# Training loss: RMSE= 21.120290402043874
# T49 660
# T141 510
# ----------------------
# 20000159
# upper_bound 735.0
# Training Accuracy: 0.25
# Training loss: RMSE= 15.253414918196734
# T37 660
# T142 660
# ----------------------
# 20000410
# upper_bound 660.0
# Training Accuracy: 0.7857142857142857
# Training loss: RMSE= 1.889822365046136
# T143 585
# T164 585
# ----------------------
# 20000123
# upper_bound 615.0
# Training Accuracy: 0.7222222222222222
# Training loss: RMSE= 12.5210933139953
# T144 390
# ----------------------
# 20000040
# upper_bound 675.0
# Training Accuracy: 0.45454545454545453
# Training loss: RMSE= 12.056684302229879
# T145 495
# ----------------------
# 20000502
# upper_bound 735.0
# Training Accuracy: 0.5882352941176471
# Training loss: RMSE= 10.332700802904967
# T146 435
# T200 435
# ----------------------
# 20000144
# upper_bound 630.0
# ----------------------
# 20000053
# upper_bound 585.0
# Training Accuracy: 0.8666666666666667
# Training loss: RMSE= 3.1937438845342623
# T148 405
# ----------------------
# 20000510
# upper_bound 780.0
# ----------------------
# 20000171
# upper_bound 570.0
# Training Accuracy: 0.6774193548387096
# Training loss: RMSE= 7.810249675906654
# T151 255
# T163 570
# ----------------------
# 20000207
# upper_bound 675.0
# Training Accuracy: 0.9047619047619048
# Training loss: RMSE= 7.715167498104596
# T152 345
# T325 345
# ----------------------
# 20000099
# upper_bound 585.0
# Training Accuracy: 0.8125
# Training loss: RMSE= 6.45174395028197
# T153 330
# ----------------------
# 20000440
# upper_bound 615.0
# Training Accuracy: 0.9473684210526315
# Training loss: RMSE= 2.752988806446741
# T16 330
# T154 300
# ----------------------
# 20000158
# upper_bound 600.0
# Training Accuracy: 0.29411764705882354
# Training loss: RMSE= 7.638909685057848
# T155 375
# T298 570
# ----------------------
# 20000543
# upper_bound 660.0
# Training Accuracy: 0.5454545454545454
# Training loss: RMSE= 7.298816840606927
# T156 495
# ----------------------
# 20000017
# upper_bound 570.0
# Training Accuracy: 0.38461538461538464
# Training loss: RMSE= 7.253646297923867
# T13 360
# T157 360
# ----------------------
# 20000698
# upper_bound 600.0
# Training Accuracy: 0.9230769230769231
# Training loss: RMSE= 1.941450686788302
# T158 510
# ----------------------
# 20000391
# upper_bound 630.0
# Training Accuracy: 0.9090909090909091
# Training loss: RMSE= 5.334280218974763
# T159 555
# T322 585
# ----------------------
# 20000657
# upper_bound 630.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T160 495
# ----------------------
# 20000429
# upper_bound 570.0
# Training Accuracy: 0.5238095238095238
# Training loss: RMSE= 9.509393851795783
# T161 420
# ----------------------
# 20000249
# upper_bound 630.0
# Training Accuracy: 0.25806451612903225
# Training loss: RMSE= 14.771375981508857
# T91 255
# T162 330
# ----------------------
# 20000171
# upper_bound 570.0
# Training Accuracy: 0.6774193548387096
# Training loss: RMSE= 7.810249675906654
# T151 255
# T163 570
# ----------------------
# 20000410
# upper_bound 660.0
# Training Accuracy: 0.7857142857142857
# Training loss: RMSE= 1.889822365046136
# T143 585
# T164 585
# ----------------------
# 20000407
# upper_bound 600.0
# ----------------------
# 20000109
# upper_bound 660.0
# Training Accuracy: 0.2
# Training loss: RMSE= 10.356962231594101
# T167 645
# T309 645
# ----------------------
# 20000180
# upper_bound 630.0
# Training Accuracy: 0.3
# Training loss: RMSE= 11.211601134539169
# T168 495
# ----------------------
# 20000649
# upper_bound 555.0
# Training Accuracy: 0.7142857142857143
# Training loss: RMSE= 7.131419413913534
# T63 180
# T169 180
# ----------------------
# 20000128
# upper_bound 615.0
# Training Accuracy: 0.7142857142857143
# Training loss: RMSE= 5.41162769282166
# T170 585
# ----------------------
# 20000685
# upper_bound 540.0
# Training Accuracy: 0.9090909090909091
# Training loss: RMSE= 1.5075567228888183
# T171 270
# ----------------------
# 20000054
# upper_bound 630.0
# Training Accuracy: 0.7727272727272727
# Training loss: RMSE= 8.323023925997525
# T172 525
# ----------------------
# 20000118
# upper_bound 555.0
# Training Accuracy: 0.4117647058823529
# Training loss: RMSE= 8.626225403146057
# T173 300
# T290 510
# ----------------------
# 20000624
# upper_bound 600.0
# Training Accuracy: 0.7241379310344828
# Training loss: RMSE= 7.339078209524493
# T88 360
# T174 0
# ----------------------
# 20000453
# upper_bound 570.0
# Training Accuracy: 0.55
# Training loss: RMSE= 5.472659317004851
# T175 360
# ----------------------
# 20000488
# upper_bound 660.0
# Training Accuracy: 0.5652173913043478
# Training loss: RMSE= 10.603526894797582
# T80 255
# T176 555
# ----------------------
# 20000163
# upper_bound 855.0
# Training Accuracy: 0.23529411764705882
# Training loss: RMSE= 12.383575460119367
# T177 465
# ----------------------
# 20000261
# upper_bound 645.0
# Training Accuracy: 0.8125
# Training loss: RMSE= 6.149186938124422
# T178 585
# ----------------------
# 20000452
# upper_bound 660.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T179 555
# ----------------------
# 20000403
# upper_bound 390.0
# Training Accuracy: 0.3695652173913043
# Training loss: RMSE= 14.303389686425351
# T180 360
# ----------------------
# 20000235
# upper_bound 615.0
# Training Accuracy: 0.625
# Training loss: RMSE= 12.128221221597173
# T181 450
# ----------------------
# 20000464
# upper_bound 675.0
# Training Accuracy: 0.9090909090909091
# Training loss: RMSE= 2.7136021011998723
# T182 450
# ----------------------
# 20000276
# upper_bound 690.0
# Training Accuracy: 0.23333333333333334
# Training loss: RMSE= 14.045165241700316
# T183 615
# ----------------------
# 20000250
# upper_bound 645.0
# Training Accuracy: 0.4
# Training loss: RMSE= 11.46298390472568
# T24 450
# T184 150
# T295 570
# ----------------------
# 20000166
# upper_bound 585.0
# Training Accuracy: 0.782608695652174
# Training loss: RMSE= 9.53711286182199
# T185 585
# ----------------------
# 20000377
# upper_bound 645.0
# ----------------------
# 20000146
# upper_bound 570.0
# Training Accuracy: 0.8125
# Training loss: RMSE= 4.130677910464576
# T187 330
# ----------------------
# 20000436
# upper_bound 690.0
# Training Accuracy: 0.5555555555555556
# Training loss: RMSE= 10.438532605829373
# T84 450
# T188 390
# T317 390
# ----------------------
# 20000483
# upper_bound 570.0
# Training Accuracy: 0.1794871794871795
# Training loss: RMSE= 12.074554724496958
# T189 450
# ----------------------
# 20000653
# upper_bound 600.0
# Training Accuracy: 0.7
# Training loss: RMSE= 7.871890920653478
# T45 465
# T190 465
# ----------------------
# 20000352
# upper_bound 660.0
# Training Accuracy: 0.46153846153846156
# Training loss: RMSE= 12.697667865823599
# T191 570
# ----------------------
# 20000295
# upper_bound 495.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T192 465
# ----------------------
# 20000121
# upper_bound 750.0
# ----------------------
# 20000349
# upper_bound 660.0
# Training Accuracy: 0.8235294117647058
# Training loss: RMSE= 7.328429733097069
# T75 615
# T194 420
# ----------------------
# 20000340
# upper_bound 645.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T195 405
# ----------------------
# 20000129
# upper_bound 705.0
# Training Accuracy: 0.7692307692307693
# Training loss: RMSE= 6.928203230275509
# T34 0
# T196 645
# T263 630
# ----------------------
# 20000347
# upper_bound 705.0
# Training Accuracy: 0.9285714285714286
# Training loss: RMSE= 6.68153104781061
# T198 615
# ----------------------
# 20000057
# upper_bound 570.0
# Training Accuracy: 0.6428571428571429
# Training loss: RMSE= 4.888032031693036
# T199 480
# ----------------------
# 20000502
# upper_bound 735.0
# Training Accuracy: 0.5882352941176471
# Training loss: RMSE= 10.332700802904967
# T146 435
# T200 435
# ----------------------
# 20000596
# upper_bound 645.0
# Training Accuracy: 0.45
# Training loss: RMSE= 16.127616066858735
# T125 300
# T201 300
# ----------------------
# 20000574
# upper_bound 615.0
# Training Accuracy: 0.7666666666666667
# Training loss: RMSE= 5.344779384283945
# T107 540
# T202 420
# ----------------------
# 20000222
# upper_bound 645.0
# Training Accuracy: 0.6666666666666666
# Training loss: RMSE= 6.620674688680402
# T203 435
# ----------------------
# 20000338
# upper_bound 630.0
# Training Accuracy: 0.8333333333333334
# Training loss: RMSE= 1.20761472884912
# T18 615
# T204 390
# ----------------------
# 20000381
# upper_bound 615.0
# Training Accuracy: 0.7619047619047619
# Training loss: RMSE= 4.680252333449758
# T36 30
# T205 420
# ----------------------
# 20000213
# upper_bound 600.0
# Training Accuracy: 0.6666666666666666
# Training loss: RMSE= 6.331139971074193
# T206 420
# ----------------------
# 20000687
# upper_bound 615.0
# Training Accuracy: 0.4
# Training loss: RMSE= 7.758865896508329
# T207 0
# ----------------------
# 20000356
# upper_bound 615.0
# Training Accuracy: 0.4782608695652174
# Training loss: RMSE= 9.982593546420864
# T208 330
# ----------------------
# 20000312
# upper_bound 1005.0
# ----------------------
# 20000591
# upper_bound 585.0
# Training Accuracy: 0.5416666666666666
# Training loss: RMSE= 8.374067112222113
# T127 375
# T210 405
# ----------------------
# 20000361
# upper_bound 570.0
# Training Accuracy: 0.34782608695652173
# Training loss: RMSE= 8.871056993048407
# T211 555
# T262 330
# ----------------------
# 20000446
# upper_bound 615.0
# Training Accuracy: 0.7777777777777778
# Training loss: RMSE= 7.9744963848880515
# T212 360
# ----------------------
# 20000243
# upper_bound 600.0
# Training Accuracy: 0.8235294117647058
# Training loss: RMSE= 7.611910172262165
# T213 555
# ----------------------
# 20000456
# upper_bound 630.0
# Training Accuracy: 0.45454545454545453
# Training loss: RMSE= 12.079283542871693
# T214 495
# ----------------------
# 20000450
# upper_bound 570.0
# Training Accuracy: 0.375
# Training loss: RMSE= 14.265342617687105
# T215 555
# T302 255
# ----------------------
# 20000632
# upper_bound 555.0
# Training Accuracy: 0.2413793103448276
# Training loss: RMSE= 12.366528796827291
# T216 405
# ----------------------
# 20000387
# upper_bound 660.0
# Training Accuracy: 0.9
# Training loss: RMSE= 6.296824596572466
# T217 465
# ----------------------
# 20000421
# upper_bound 615.0
# Training Accuracy: 0.6842105263157895
# Training loss: RMSE= 3.9868203925064476
# T218 270
# ----------------------
# 20000562
# upper_bound 645.0
# Training Accuracy: 0.1875
# Training loss: RMSE= 12.119199643540822
# T219 420
# ----------------------
# 20000455
# upper_bound 585.0
# Training Accuracy: 0.875
# Training loss: RMSE= 5.32290647422377
# T220 540
# ----------------------
# 20000362
# upper_bound 525.0
# Training Accuracy: 0.4
# Training loss: RMSE= 6.319282659711728
# T221 330
# ----------------------
# 20000311
# upper_bound 750.0
# Training Accuracy: 0.8695652173913043
# Training loss: RMSE= 6.0756105436623296
# T51 465
# T222 465
# ----------------------
# 20000067
# upper_bound 600.0
# Training Accuracy: 0.8076923076923077
# Training loss: RMSE= 5.266001256244555
# T223 465
# T303 240
# ----------------------
# 20000363
# upper_bound 765.0
# Training Accuracy: 0.5789473684210527
# Training loss: RMSE= 15.744673284705062
# T224 675
# ----------------------
# 20000612
# upper_bound 615.0
# Training Accuracy: 0.6538461538461539
# Training loss: RMSE= 5.262348115842175
# T92 435
# T225 435
# T304 435
# ----------------------
# 20000154
# upper_bound 570.0
# Training Accuracy: 0.32142857142857145
# Training loss: RMSE= 11.833668673987551
# T226 360
# ----------------------
# 20000334
# upper_bound 630.0
# Training Accuracy: 0.9411764705882353
# Training loss: RMSE= 6.5484618759809905
# T73 270
# T227 360
# T288 570
# ----------------------
# 20000540
# upper_bound 630.0
# Training Accuracy: 0.8571428571428571
# Training loss: RMSE= 5.809475019311125
# T46 0
# T228 225
# ----------------------
# 20000539
# upper_bound 705.0
# ----------------------
# 20000434
# upper_bound 690.0
# Training Accuracy: 0.8636363636363636
# Training loss: RMSE= 8.916277250063503
# T35 465
# T100 405
# T230 615
# T256 525
# ----------------------
# 20000144
# upper_bound 630.0
# ----------------------
# 20000900
# upper_bound 570.0
# Training Accuracy: 0.9411764705882353
# Training loss: RMSE= 0.24253562503633297
# T232 480
# ----------------------
# 20000167
# upper_bound 495.0
# Training Accuracy: 0.4827586206896552
# Training loss: RMSE= 13.023850799789301
# T233 285
# ----------------------
# 20000668
# upper_bound 795.0
# Training Accuracy: 0.5625
# Training loss: RMSE= 6.87386354243376
# T59 690
# T234 675
# ----------------------
# 20000454
# upper_bound 525.0
# Training Accuracy: 0.34782608695652173
# Training loss: RMSE= 9.250146884850226
# T235 330
# ----------------------
# 20000252
# upper_bound 585.0
# Training Accuracy: 0.7083333333333334
# Training loss: RMSE= 7.700108224347672
# T236 420
# ----------------------
# 20000304
# upper_bound 585.0
# Training Accuracy: 0.30303030303030304
# Training loss: RMSE= 7.63365752917481
# T237 450
# ----------------------
# 20000554
# upper_bound 570.0
# Training Accuracy: 0.7
# Training loss: RMSE= 8.966604708583958
# T238 390
# ----------------------
# 20000112
# upper_bound 645.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T101 255
# T239 510
# ----------------------
# 20000185
# upper_bound 615.0
# ----------------------
# 20000303
# upper_bound 585.0
# Training Accuracy: 0.9565217391304348
# Training loss: RMSE= 2.0851441405707476
# T241 300
# ----------------------
# 20000081
# upper_bound 615.0
# Training Accuracy: 0.52
# Training loss: RMSE= 8.423775875461075
# T53 420
# T242 525
# T307 420
# ----------------------
# 20000424
# upper_bound 525.0
# Training Accuracy: 0.7777777777777778
# Training loss: RMSE= 3.8297084310253524
# T243 420
# ----------------------
# 20000665
# upper_bound 585.0
# Training Accuracy: 0.64
# Training loss: RMSE= 12.111151885762148
# T244 300
# ----------------------
# 20000026
# upper_bound 555.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T110 180
# T245 555
# ----------------------
# 20000012
# upper_bound 600.0
# Training Accuracy: 0.48148148148148145
# Training loss: RMSE= 6.738501866691691
# T246 600
# ----------------------
# 20000603
# upper_bound 615.0
# Training Accuracy: 0.7692307692307693
# Training loss: RMSE= 8.602325267042627
# T58 330
# T247 345
# ----------------------
# 20000525
# upper_bound 570.0
# Training Accuracy: 0.44
# Training loss: RMSE= 7.149825172687791
# T248 540
# ----------------------
# 20000108
# upper_bound 585.0
# Training Accuracy: 0.3333333333333333
# Training loss: RMSE= 9.735387911006821
# T2 405
# T249 450
# ----------------------
# 20000492
# upper_bound 540.0
# Training Accuracy: 0.5277777777777778
# Training loss: RMSE= 7.2264944628929335
# T4 465
# T250 315
# ----------------------
# 20000664
# upper_bound 600.0
# Training Accuracy: 0.5652173913043478
# Training loss: RMSE= 11.137480786105517
# T11 525
# T251 390
# ----------------------
# 20000503
# upper_bound 510.0
# Training Accuracy: 0.5333333333333333
# Training loss: RMSE= 8.752142594816426
# T9 255
# T138 315
# T252 240
# ----------------------
# 20000256
# upper_bound 630.0
# Training Accuracy: 0.6666666666666666
# Training loss: RMSE= 7.5249584716462055
# T74 300
# T253 300
# ----------------------
# 20000285
# upper_bound 600.0
# Training Accuracy: 0.8148148148148148
# Training loss: RMSE= 4.682512779045662
# T40 0
# T254 555
# ----------------------
# 20000245
# upper_bound 585.0
# Training Accuracy: 0.68
# Training loss: RMSE= 9.258509599282165
# T62 240
# T255 480
# ----------------------
# 20000434
# upper_bound 690.0
# Training Accuracy: 0.8636363636363636
# Training loss: RMSE= 8.916277250063503
# T35 465
# T100 405
# T230 615
# T256 525
# ----------------------
# 20000406
# upper_bound 600.0
# Training Accuracy: 0.21428571428571427
# Training loss: RMSE= 12.88825600526087
# T257 150
# ----------------------
# 20000239
# upper_bound 630.0
# Training Accuracy: 0.4666666666666667
# Training loss: RMSE= 6.995236474439826
# T258 255
# ----------------------
# 20000426
# upper_bound 705.0
# Training Accuracy: 0.9333333333333333
# Training loss: RMSE= 9.03696114115064
# T259 645
# ----------------------
# 20000190
# upper_bound 600.0
# Training Accuracy: 0.3333333333333333
# Training loss: RMSE= 7.297259759663212
# T260 495
# ----------------------
# 20000192
# upper_bound 615.0
# Training Accuracy: 0.15789473684210525
# Training loss: RMSE= 14.8270733883379
# T261 465
# ----------------------
# 20000361
# upper_bound 570.0
# Training Accuracy: 0.34782608695652173
# Training loss: RMSE= 8.871056993048407
# T211 555
# T262 330
# ----------------------
# 20000129
# upper_bound 705.0
# Training Accuracy: 0.7692307692307693
# Training loss: RMSE= 6.928203230275509
# T34 0
# T196 645
# T263 630
# ----------------------
# 20000548
# upper_bound 600.0
# Training Accuracy: 0.42105263157894735
# Training loss: RMSE= 8.094832659757316
# T264 330
# T310 570
# ----------------------
# 20000263
# upper_bound 570.0
# Training Accuracy: 0.34375
# Training loss: RMSE= 9.094984881790623
# T27 570
# T265 495
# ----------------------
# 20000333
# upper_bound 570.0
# Training Accuracy: 0.6153846153846154
# Training loss: RMSE= 4.996152365724894
# T266 315
# ----------------------
# 20000197
# upper_bound 630.0
# Training Accuracy: 0.782608695652174
# Training loss: RMSE= 4.768556430910995
# T267 15
# ----------------------
# 20000565
# upper_bound 570.0
# Training Accuracy: 0.8421052631578947
# Training loss: RMSE= 5.812871380325779
# T268 390
# T312 360
# ----------------------
# 20000307
# upper_bound 645.0
# Training Accuracy: 0.5675675675675675
# Training loss: RMSE= 10.168844841249443
# T269 300
# ----------------------
# 20000678
# upper_bound 615.0
# Training Accuracy: 0.6666666666666666
# Training loss: RMSE= 7.76940386153509
# T270 600
# ----------------------
# 20000351
# upper_bound 585.0
# Training Accuracy: 0.7777777777777778
# Training loss: RMSE= 4.264409124976775
# T271 270
# ----------------------
# 20000560
# upper_bound 555.0
# Training Accuracy: 0.5357142857142857
# Training loss: RMSE= 7.768985960673558
# T93 555
# T272 345
# ----------------------
# 20000431
# upper_bound 585.0
# Training Accuracy: 0.4166666666666667
# Training loss: RMSE= 14.146554350795109
# T273 570
# ----------------------
# 20000686
# upper_bound 540.0
# Training Accuracy: 0.3548387096774194
# Training loss: RMSE= 10.030598348344252
# T130 315
# T274 345
# ----------------------
# 20000005
# upper_bound 555.0
# Training Accuracy: 0.7666666666666667
# Training loss: RMSE= 4.58257569495584
# T129 240
# T276 420
# ----------------------
# 20000395
# upper_bound 705.0
# Training Accuracy: 0.6071428571428571
# Training loss: RMSE= 11.695542496426333
# T277 600
# ----------------------
# 20000529
# upper_bound 600.0
# Training Accuracy: 0.34285714285714286
# Training loss: RMSE= 12.42692928396116
# T278 330
# ----------------------
# 20000015
# upper_bound 615.0
# Training Accuracy: 0.56
# Training loss: RMSE= 15.656308632624741
# T279 345
# ----------------------
# 20000626
# upper_bound 600.0
# Training Accuracy: 0.43333333333333335
# Training loss: RMSE= 9.212310604113751
# T280 405
# ----------------------
# 20000476
# upper_bound 465.0
# Training Accuracy: 0.4838709677419355
# Training loss: RMSE= 6.458302982932501
# T136 390
# T281 270
# ----------------------
# 20000136
# upper_bound 645.0
# Training Accuracy: 0.21428571428571427
# Training loss: RMSE= 14.280356138016005
# T282 465
# ----------------------
# 20000577
# upper_bound 615.0
# Training Accuracy: 0.15384615384615385
# Training loss: RMSE= 9.942140305092956
# T283 570
# ----------------------
# 20000517
# upper_bound 570.0
# Training Accuracy: 0.9629629629629629
# Training loss: RMSE= 4.041451884327381
# T284 390
# ----------------------
# 20000009
# upper_bound 645.0
# Training Accuracy: 0.5416666666666666
# Training loss: RMSE= 10.781929326423912
# T285 240
# ----------------------
# 20000105
# upper_bound 555.0
# Training Accuracy: 0.6538461538461539
# Training loss: RMSE= 7.861786839370062
# T286 540
# ----------------------
# 20000499
# upper_bound 615.0
# Training Accuracy: 0.3333333333333333
# Training loss: RMSE= 16.63079472945696
# T287 480
# ----------------------
# 20000334
# upper_bound 630.0
# Training Accuracy: 0.9411764705882353
# Training loss: RMSE= 6.5484618759809905
# T73 270
# T227 360
# T288 570
# ----------------------
# 20000463
# upper_bound 465.0
# Training Accuracy: 0.46153846153846156
# Training loss: RMSE= 8.993587459107482
# T289 450
# ----------------------
# 20000118
# upper_bound 555.0
# Training Accuracy: 0.4117647058823529
# Training loss: RMSE= 8.626225403146057
# T173 300
# T290 510
# ----------------------
# 20000513
# upper_bound 585.0
# Training Accuracy: 0.55
# Training loss: RMSE= 10.370631610466162
# T291 0
# ----------------------
# 20000460
# upper_bound 645.0
# Training Accuracy: 0.6666666666666666
# Training loss: RMSE= 6.928203230275509
# T21 510
# T292 420
# ----------------------
# 20000342
# upper_bound 570.0
# Training Accuracy: 0.5
# Training loss: RMSE= 10.014275524755362
# T293 375
# ----------------------
# 20000494
# upper_bound 540.0
# Training Accuracy: 0.13333333333333333
# Training loss: RMSE= 12.519318405301997
# T294 480
# ----------------------
# 20000250
# upper_bound 645.0
# Training Accuracy: 0.4
# Training loss: RMSE= 11.46298390472568
# T24 450
# T184 150
# T295 570
# ----------------------
# 20000021
# upper_bound 675.0
# Training Accuracy: 0.7647058823529411
# Training loss: RMSE= 8.408678989766535
# T296 630
# ----------------------
# 20000148
# upper_bound 555.0
# Training Accuracy: 0.23529411764705882
# Training loss: RMSE= 11.874342087037917
# T297 390
# ----------------------
# 20000158
# upper_bound 600.0
# Training Accuracy: 0.29411764705882354
# Training loss: RMSE= 7.638909685057848
# T155 375
# T298 570
# ----------------------
# 20000693
# upper_bound 705.0
# ----------------------
# 20000051
# upper_bound 675.0
# Training Accuracy: 0.7619047619047619
# Training loss: RMSE= 6.644009116704849
# T300 450
# ----------------------
# 20000100
# upper_bound 720.0
# ----------------------
# 20000450
# upper_bound 570.0
# Training Accuracy: 0.375
# Training loss: RMSE= 14.265342617687105
# T215 555
# T302 255
# ----------------------
# 20000067
# upper_bound 600.0
# Training Accuracy: 0.8076923076923077
# Training loss: RMSE= 5.266001256244555
# T223 465
# T303 240
# ----------------------
# 20000612
# upper_bound 615.0
# Training Accuracy: 0.6538461538461539
# Training loss: RMSE= 5.262348115842175
# T92 435
# T225 435
# T304 435
# ----------------------
# 20000320
# upper_bound 570.0
# Training Accuracy: 0.6333333333333333
# Training loss: RMSE= 13.778001790293589
# T305 285
# ----------------------
# 20000047
# upper_bound 555.0
# Training Accuracy: 0.8181818181818182
# Training loss: RMSE= 6.007570980929738
# T70 465
# T306 285
# ----------------------
# 20000081
# upper_bound 615.0
# Training Accuracy: 0.52
# Training loss: RMSE= 8.423775875461075
# T53 420
# T242 525
# T307 420
# ----------------------
# 20000542
# upper_bound 630.0
# Training Accuracy: 0.43333333333333335
# Training loss: RMSE= 13.745302227791623
# T1 390
# T308 525
# ----------------------
# 20000109
# upper_bound 660.0
# Training Accuracy: 0.2
# Training loss: RMSE= 10.356962231594101
# T167 645
# T309 645
# ----------------------
# 20000548
# upper_bound 600.0
# Training Accuracy: 0.42105263157894735
# Training loss: RMSE= 8.094832659757316
# T264 330
# T310 570
# ----------------------
# 20000247
# upper_bound 615.0
# Training Accuracy: 0.8125
# Training loss: RMSE= 6.041522986797286
# T26 390
# T311 435
# ----------------------
# 20000565
# upper_bound 570.0
# Training Accuracy: 0.8421052631578947
# Training loss: RMSE= 5.812871380325779
# T268 390
# T312 360
# ----------------------
# 20000383
# upper_bound 645.0
# Training Accuracy: 0.7333333333333333
# Training loss: RMSE= 6.137317546507322
# T122 495
# T313 630
# ----------------------
# 20000345
# upper_bound 645.0
# Training Accuracy: 0.37037037037037035
# Training loss: RMSE= 10.723805294763608
# T314 345
# ----------------------
# 20000486
# upper_bound 615.0
# Training Accuracy: 0.25
# Training loss: RMSE= 9.522529675909203
# T315 420
# ----------------------
# 20000496
# upper_bound 645.0
# Training Accuracy: 0.8571428571428571
# Training loss: RMSE= 11.417405259389843
# T316 345
# ----------------------
# 20000436
# upper_bound 690.0
# Training Accuracy: 0.5555555555555556
# Training loss: RMSE= 10.438532605829373
# T84 450
# T188 390
# T317 390
# ----------------------
# 20000325
# upper_bound 555.0
# Training Accuracy: 0.46875
# Training loss: RMSE= 8.651228236499138
# T318 480
# ----------------------
# 20000281
# upper_bound 690.0
# Training Accuracy: 0.8333333333333334
# Training loss: RMSE= 7.984359711335656
# T319 435
# ----------------------
# 20000549
# upper_bound 585.0
# Training Accuracy: 0.5789473684210527
# Training loss: RMSE= 9.784520535277299
# T320 450
# ----------------------
# 20000393
# upper_bound 780.0
# Training Accuracy: 0.42857142857142855
# Training loss: RMSE= 8.73007936471861
# T321 465
# ----------------------
# 20000391
# upper_bound 630.0
# Training Accuracy: 0.9090909090909091
# Training loss: RMSE= 5.334280218974763
# T159 555
# T322 585
# ----------------------
# 20000430
# upper_bound 570.0
# Training Accuracy: 0.36363636363636365
# Training loss: RMSE= 9.460443964212251
# T323 210
# ----------------------
# 20000020
# upper_bound 555.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T324 180
# ----------------------
# 20000207
# upper_bound 675.0
# Training Accuracy: 0.9047619047619048
# Training loss: RMSE= 7.715167498104596
# T152 345
# T325 345
# ----------------------
# 20000667
# upper_bound 555.0
# Training Accuracy: 0.8947368421052632
# Training loss: RMSE= 0.8271701918685112
# T326 450
# ----------------------
# 20000255
# upper_bound 615.0
# Training Accuracy: 0.65
# Training loss: RMSE= 6.859300255857007
# T56 270
# T327 390
# ----------------------
# 20000312
# upper_bound 1005.0
# Training Accuracy: 0.8
# Training loss: RMSE= 3.1304951684997055
# T14 345
# T209 90
# ----------------------
# 20000547
# upper_bound 570.0
# Training Accuracy: 0.8695652173913043
# Training loss: RMSE= 2.4583486857786396
# T57 360
# ----------------------
# 20000071
# upper_bound 615.0
# Training Accuracy: 0.6153846153846154
# Training loss: RMSE= 7.411010519698169
# T95 375
# ----------------------
# 20000682
# upper_bound 705.0
# Training Accuracy: 0.92
# Training loss: RMSE= 1.61245154965971
# T114 555
# ----------------------
# 20000049
# upper_bound 705.0
# Training Accuracy: 0.6363636363636364
# Training loss: RMSE= 8.890751067567606
# T121 405
# ----------------------
# 20000248
# upper_bound 600.0
# ----------------------
# 20000144
# upper_bound 630.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T147 450
# T231 450
# ----------------------
# 20000510
# upper_bound 780.0
# Training Accuracy: 0.6666666666666666
# Training loss: RMSE= 10.082988974836116
# T149 480
# ----------------------
# 20000407
# upper_bound 600.0
# Training Accuracy: 0.9333333333333333
# Training loss: RMSE= 0.2581988897471611
# T166 330
# ----------------------
# 20000377
# upper_bound 645.0
# Training Accuracy: 0.9166666666666666
# Training loss: RMSE= 4.932882862316247
# T186 540
# ----------------------
# 20000121
# upper_bound 750.0
# Training Accuracy: 0.14285714285714285
# Training loss: RMSE= 18.2208671582886
# T193 675
# ----------------------
# 20000312
# upper_bound 1005.0
# Training Accuracy: 0.8
# Training loss: RMSE= 3.1304951684997055
# T14 345
# T209 90
# ----------------------
# 20000539
# upper_bound 705.0
# Training Accuracy: 0.65
# Training loss: RMSE= 12.965338406690355
# T229 375
# ----------------------
# 20000144
# upper_bound 630.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T147 450
# T231 450
# ----------------------
# 20000185
# upper_bound 615.0
# Training Accuracy: 0.7142857142857143
# Training loss: RMSE= 9.19627253681776
# T240 615
# ----------------------
# 20000693
# upper_bound 705.0
# Training Accuracy: 0.9444444444444444
# Training loss: RMSE= 0.9428090415820634
# T299 360
# ----------------------
# 20000100
# upper_bound 720.0
# Training Accuracy: 0.4375
# Training loss: RMSE= 11.367442544389657
# T301 630
# ----------------------
# 20000079
# upper_bound 675.0
# Training Accuracy: 0.34615384615384615
# Training loss: RMSE= 5.59532772120564
# T275 180
# ----------------------
# 20000206
# upper_bound 690.0
# Training Accuracy: 0.052702702702702706
# Training loss: RMSE= 13.579097609631205
# T118 540
# T197 540
# CPU times: user 46.2 s, sys: 352 ms, total: 46.5 s
# Wall time: 44.8 s

# %%
# ValueError: With n_samples=52, test_size=0.99 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.
20000079

# ValueError: Internal work array size computation failed: -10
20000206
# Out:
# 20000206

# %%
not_ok_2 = []
for taxi_id in not_ok:
    print('----------------------')
    print(taxi_id)
    trips, output = lda_complete(taxi_id=taxi_id, is_cut=True, cutoff=0.5, test_size=0.98)
    if output is None:
        not_ok_2.append(taxi_id)
    else:
        r = len(trips)

        for i in range(r):
            all_trips.append(trips[i])
            all_preds.append(output[i])
# Out:
# ----------------------
# 20000312
# upper_bound 1005.0
# Training Accuracy: 0.8
# Training loss: RMSE= 3.1304951684997055
# T14 345
# T209 90
# ----------------------
# 20000547
# upper_bound 570.0
# Training Accuracy: 0.8695652173913043
# Training loss: RMSE= 2.4583486857786396
# T57 360
# ----------------------
# 20000071
# upper_bound 615.0
# Training Accuracy: 0.6153846153846154
# Training loss: RMSE= 7.411010519698169
# T95 375
# ----------------------
# 20000682
# upper_bound 705.0
# Training Accuracy: 0.92
# Training loss: RMSE= 1.61245154965971
# T114 555
# ----------------------
# 20000049
# upper_bound 705.0
# Training Accuracy: 0.6363636363636364
# Training loss: RMSE= 8.890751067567606
# T121 405
# ----------------------
# 20000248
# upper_bound 600.0
# ----------------------
# 20000144
# upper_bound 630.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T147 450
# T231 450
# ----------------------
# 20000510
# upper_bound 780.0
# Training Accuracy: 0.6666666666666666
# Training loss: RMSE= 10.082988974836116
# T149 480
# ----------------------
# 20000407
# upper_bound 600.0
# Training Accuracy: 0.9333333333333333
# Training loss: RMSE= 0.2581988897471611
# T166 330
# ----------------------
# 20000377
# upper_bound 645.0
# Training Accuracy: 0.9166666666666666
# Training loss: RMSE= 4.932882862316247
# T186 540
# ----------------------
# 20000121
# upper_bound 750.0
# Training Accuracy: 0.14285714285714285
# Training loss: RMSE= 18.2208671582886
# T193 675
# ----------------------
# 20000312
# upper_bound 1005.0
# Training Accuracy: 0.8
# Training loss: RMSE= 3.1304951684997055
# T14 345
# T209 90
# ----------------------
# 20000539
# upper_bound 705.0
# Training Accuracy: 0.65
# Training loss: RMSE= 12.965338406690355
# T229 375
# ----------------------
# 20000144
# upper_bound 630.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T147 450
# T231 450
# ----------------------
# 20000185
# upper_bound 615.0
# Training Accuracy: 0.7142857142857143
# Training loss: RMSE= 9.19627253681776
# T240 615
# ----------------------
# 20000693
# upper_bound 705.0
# Training Accuracy: 0.9444444444444444
# Training loss: RMSE= 0.9428090415820634
# T299 360
# ----------------------
# 20000100
# upper_bound 720.0
# Training Accuracy: 0.4375
# Training loss: RMSE= 11.367442544389657
# T301 630

# %%
trips, output = lda_complete(taxi_id=not_ok_2[0], is_cut=True, cutoff=0.5, test_size=0.94)
r = len(trips)

for i in range(r):
    all_trips.append(trips[i])
    all_preds.append(output[i])
# Out:
# upper_bound 600.0
# Training Accuracy: 1.0
# Training loss: RMSE= 0.0
# T126 555

# %%
weird = [20000079, 20000206]
for taxi_id in weird:
    print('----------------------')
    print(taxi_id)
    trips, output = lda_complete(taxi_id=taxi_id, is_cut=True, cutoff=0.5, test_size=0.5)
    if output is None:
        not_ok_2.append(taxi_id)
    else:
        r = len(trips)

        for i in range(r):
            all_trips.append(trips[i])
            all_preds.append(output[i])
# Out:
# ----------------------
# 20000079
# upper_bound 675.0
# Training Accuracy: 0.34615384615384615
# Training loss: RMSE= 5.59532772120564
# T275 180
# ----------------------
# 20000206
# upper_bound 690.0
# Training Accuracy: 0.052702702702702706
# Training loss: RMSE= 13.579097609631205
# T118 540
# T197 540

# %%
dcts=dict(zip(all_trips, all_preds))
all_ids = list(dftest.TRIP_ID)
n = len(all_ids)
for i in range(n):
    print(dcts[all_ids[i]])
# Out:
# 390
# 405
# 510
# 465
# 495
# 315
# 300
# 450
# 255
# 510
# 525
# 315
# 360
# 345
# 450
# 330
# 480
# 615
# 615
# 630
# 510
# 435
# 240
# 450
# 405
# 390
# 570
# 570
# 645
# 270
# 525
# 420
# 0
# 0
# 465
# 30
# 660
# 510
# 390
# 0
# 300
# 270
# 165
# 555
# 465
# 0
# 285
# 600
# 660
# 570
# 465
# 90
# 420
# 420
# 510
# 270
# 360
# 330
# 690
# 420
# 570
# 240
# 180
# 285
# 240
# 600
# 510
# 210
# 450
# 465
# 420
# 390
# 270
# 300
# 615
# 225
# 420
# 300
# 315
# 255
# 420
# 300
# 510
# 450
# 600
# 360
# 720
# 360
# 255
# 255
# 435
# 555
# 585
# 375
# 330
# 840
# 360
# 405
# 255
# 300
# 375
# 480
# 540
# 465
# 180
# 345
# 660
# 165
# 555
# 600
# 585
# 285
# 540
# 330
# 225
# 405
# 495
# 690
# 285
# 300
# 555
# 375
# 495
# 240
# 315
# 555
# 525
# 240
# 420
# 465
# 390
# 570
# 315
# 255
# 300
# 510
# 660
# 585
# 390
# 495
# 435
# 450
# 405
# 480
# 255
# 345
# 330
# 300
# 375
# 495
# 360
# 510
# 555
# 495
# 420
# 330
# 570
# 585
# 330
# 645
# 495
# 180
# 585
# 270
# 525
# 300
# 0
# 360
# 555
# 465
# 585
# 555
# 360
# 450
# 450
# 615
# 150
# 585
# 540
# 330
# 390
# 450
# 465
# 570
# 465
# 675
# 420
# 405
# 645
# 540
# 615
# 480
# 435
# 300
# 420
# 435
# 390
# 420
# 420
# 0
# 330
# 90
# 405
# 555
# 360
# 555
# 495
# 555
# 405
# 465
# 270
# 420
# 540
# 330
# 465
# 465
# 675
# 435
# 360
# 360
# 225
# 375
# 615
# 450
# 480
# 285
# 675
# 330
# 420
# 450
# 390
# 510
# 615
# 300
# 525
# 420
# 300
# 555
# 600
# 345
# 540
# 450
# 315
# 390
# 240
# 300
# 555
# 480
# 525
# 150
# 255
# 645
# 495
# 465
# 330
# 630
# 330
# 495
# 315
# 15
# 390
# 300
# 600
# 270
# 345
# 570
# 345
# 180
# 420
# 600
# 330
# 345
# 405
# 270
# 465
# 570
# 390
# 240
# 540
# 480
# 570
# 450
# 510
# 0
# 420
# 375
# 480
# 570
# 630
# 390
# 570
# 360
# 450
# 630
# 255
# 240
# 435
# 285
# 285
# 420
# 525
# 645
# 570
# 435
# 360
# 630
# 345
# 420
# 345
# 390
# 480
# 435
# 450
# 465
# 585
# 210
# 180
# 345
# 450
# 390

# %% [markdown]
# # LDA
# ### Lower bound >= 1050 (i.e. 15 * 70)

# %%
def lda_complete_2(taxi_id, is_cut=True, cutoff=1050, test_size=0.99):
    newtrain=dftrain[dftrain['TAXI_ID'] == taxi_id]
    
    train_corr=newtrain[['TRAVEL_TIME', 'YEAR', 'MONTH', 'WEEK', 'DAY', 'HOUR', 'MIN', 'WEEKDAY']].corr()
    positive_corr_list=list(train_corr[train_corr > 0]['TRAVEL_TIME'].dropna().keys())
    positive_corr_list.remove('TRAVEL_TIME')
    
    ## outlier cut
    tmpdf = newtrain
    if is_cut:
        lower_bound = cutoff

    new_train = newtrain[newtrain.TRAVEL_TIME >= lower_bound]

    print('lower_bound', lower_bound)
    
    avail_times = new_train.TRAVEL_TIME.unique()
    n = len(avail_times)
    range_ = list(range(n))
    labels = dict(zip(avail_times,range_))
    labels_rev = dict(zip(range_, avail_times))
    
    X = []
    y = []

    for row in new_train.iterrows():

        lst = []
        for elem in positive_corr_list:
            lst.append(row[1][elem])

        X.append(np.array(lst))
        y.append(np.array(labels[row[1]['TRAVEL_TIME']]))
    
    # Split the dataset into training and testing sets
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=test_size, random_state=42)
    
    ytrain = []
    for i in y_train:
        ytrain.append(i.item())
        
    if len(set(ytrain)) >= len(X_train):
        return (None, None)
    
    # Create an LDA classifier
    lda = LinearDiscriminantAnalysis()

    # Fit the LDA model on the training data
    lda.fit(X_train, y_train)

    # Predict the class labels for the test data
    y_pred = lda.predict(X_train)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_train, y_pred)
    print("Training Accuracy:", accuracy)
    
    new_test = dftest[dftest.TAXI_ID == taxi_id]
    
    Xtest = []
    trips = []
    
    for row in new_test.iterrows():
        trips.append(row[1]['TRIP_ID'])
        lst = []
        for elem in positive_corr_list:#, 'WEEKDAY']:
            lst.append(row[1][elem])
        Xtest.append(np.array(lst))
    
    preds = lda.predict(Xtest)
    r = len(preds)
    output = []
    for i in range(r):
        print(trips[i], labels_rev[preds[i]])
        output.append(labels_rev[preds[i]])
    return (trips, output)

# %% [markdown]
# ## Randomness
# - We recorded the list of random indices (to swap the predictive results with another model) that give us the best model
# - Unfortunately, we only printed out those random indices when experimenting with this technique (and submitting the results into Kaggle) using ```print()```, but we didn't record the random seed that potentially generated this list
# - To get a list of random indices, we can do: ```random.sample(range(len(trips_with_uniq_taxi_ids)), 30)```

# %%
value_counts = dftest['TAXI_ID'].value_counts()
unique_values = value_counts.index.tolist()#value_counts[value_counts == 1].index.tolist()

# %%
trips_with_uniq_taxi_ids = list(sorted(dftest[dftest['TAXI_ID'].isin(unique_values)]['TRIP_ID']))

# %%
# to get this list of random indices, we can do: random.sample(range(len(trips_with_uniq_taxi_ids)), 30)
# we didn't set a fixed seed when generating these indices, but we had printed out the best result 
# the followings are 6 lists of random indices (stored in a dictionary) that generate the best result
random_indices = {}

# %%
random_indices[0] = [59,138,52,86,301,226,133,239,294,318,82,220,278,1,115,210,253,242,89,135,317,107,292,103,192,130,291,313,42,166]
random_indices[1] = [120,59,292,210,305,130,134,301,82,220,295,116,24,277,33,318,78,135,52,291,166,51,294,317,192,42,86,63,103,245]
random_indices[2] = [291,52,82,305,114,107,242,239,292,51,42,1,24,116,317,138,253,252,313,277,318,278,127,301,295,120,78,220,166,210]
random_indices[3] = [294,86,1,220,301,24,141,114,134,135,166,127,305,192,120,103,83,116,126,317,51,82,59,115,242,63,277,253,210,133]
random_indices[4] = [292,138,133,24,127,120,134,116,313,239,220,59,294,166,33,301,89,130,126,318,115,52,135,114,86,252,63,1,305,317]
random_indices[5] = [103,245,317,1,210,192,86,130,59,127,242,135,120,292,82,114,63,52,226,116,133,318,115,107,51,33,239,305,295,89]
#[0, 16, 27, 28, 44, 61, 62, 63, 68, 69, 72, 74, 103, 116, 124, 136, 152, 161, 174, 175], with: value_counts[value_counts == 1].index.tolist()

# %%
dcts=dict(zip(all_trips, all_preds))
for idx in range(len(random_indices)):
    random_draw = []
    for i in random_indices[idx]:
        random_draw.append(trips_with_uniq_taxi_ids[i])
        
        j = 0
        for i in random_draw: 
            if j % 2 == 1: 
                result = lda_complete_2(dftest[dftest.TRIP_ID == i]
                               .reset_index().iloc[0]['TAXI_ID'], 
                               is_cut=True, cutoff=15*150, test_size=0.1) #cutoff=15*100, test_size=0.7)
                dcts[i] = result[1][0]
            else:
                dcts[i] = 15*155
            j += 1
            print('')
# Out:
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.029069767441860465
# T118 2310
# T197 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.029069767441860465
# T118 2310
# T197 2310
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.029069767441860465
# T118 2310
# T197 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.029069767441860465
# T118 2310
# T197 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.029069767441860465
# T118 2310
# T197 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.029069767441860465
# T118 2310
# T197 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5921052631578947
# T181 2400
#
#
# lower_bound 2250
# Training Accuracy: 0.18823529411764706
# T53 2280
# T242 2700
# T307 2865
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.12037037037037036
# T321 2505
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.029069767441860465
# T118 2310
# T197 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.2251655629139073
# T74 5400
# T253 2985
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.05063291139240506
# T96 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.05063291139240506
# T96 2340
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.05063291139240506
# T96 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.08333333333333333
# T14 2835
# T209 3015
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.05063291139240506
# T96 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.08333333333333333
# T14 2835
# T209 3015
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.05063291139240506
# T96 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.08333333333333333
# T14 2835
# T209 3015
#
#
# lower_bound 2250
# Training Accuracy: 0.7692307692307693
# T16 2310
# T154 3975
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.05063291139240506
# T96 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.08333333333333333
# T14 2835
# T209 3015
#
#
# lower_bound 2250
# Training Accuracy: 0.7692307692307693
# T16 2310
# T154 3975
#
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8888888888888888
# T293 6255
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.4578313253012048
# T71 2250
# T77 2895
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.05063291139240506
# T96 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.08333333333333333
# T14 2835
# T209 3015
#
#
# lower_bound 2250
# Training Accuracy: 0.7692307692307693
# T16 2310
# T154 3975
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.03142857142857143
# T6 2625
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.03142857142857143
# T6 2625
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.03142857142857143
# T6 2625
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.03142857142857143
# T6 2625
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.03142857142857143
# T6 2625
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.4126984126984127
# T211 2580
# T262 2970
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.03142857142857143
# T6 2625
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.4126984126984127
# T211 2580
# T262 2970
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.03142857142857143
# T6 2625
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.4126984126984127
# T211 2580
# T262 2970
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.03142857142857143
# T6 2625
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.4126984126984127
# T211 2580
# T262 2970
#
#
# lower_bound 2250
# Training Accuracy: 0.21951219512195122
# T301 2385
#
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.061946902654867256
# T84 2940
# T188 3660
# T317 2580
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.8541666666666666
# T148 2430
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.0871559633027523
# T59 3315
# T234 2340
#
#
# lower_bound 2250
# Training Accuracy: 0.03142857142857143
# T6 2625
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# ...
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.058823529411764705
# T123 2745
#
#
# lower_bound 2250
# Training Accuracy: 0.4126984126984127
# T211 2580
# T262 2970
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.2251655629139073
# T74 5400
# T253 2985
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
#
# lower_bound 2250
# Training Accuracy: 0.3860759493670886
# T46 2280
# T228 4485
#
#
# lower_bound 2250
# Training Accuracy: 0.058823529411764705
# T123 2745
#
#
# lower_bound 2250
# Training Accuracy: 0.4126984126984127
# T211 2580
# T262 2970
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.5555555555555556
# T319 2250
#
#
# lower_bound 2250
# Training Accuracy: 0.9545454545454546
# T156 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.2251655629139073
# T74 5400
# T253 2985
#
#
# lower_bound 2250
# Training Accuracy: 0.06818181818181818
# T80 2880
# T176 2760
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.5757575757575758
# T36 2325
# T205 2610
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.05063291139240506
# T96 2340
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
#
# lower_bound 2250
# Training Accuracy: 0.6153846153846154
# T324 2310
#
#
# lower_bound 2250
# Training Accuracy: 0.5483870967741935
# T10 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.11688311688311688
# T277 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.06369426751592357
# T220 2460
#
#
# lower_bound 2250
# Training Accuracy: 0.6956521739130435
# T218 2475
#
#
# lower_bound 2250
# Training Accuracy: 0.2962962962962963
# T92 2265
# T225 2265
# T304 2265
#
#
# lower_bound 2250
# Training Accuracy: 0.5277777777777778
# T72 3270
#
#
# lower_bound 2250
# Training Accuracy: 0.7258064516129032
# T206 3255
#
#
# lower_bound 2250
# Training Accuracy: 0.8205128205128205
# T149 16800
#
#
# lower_bound 2250
# Training Accuracy: 0.234375
# T208 2775
#
#
# lower_bound 2250
# Training Accuracy: 0.0379746835443038
# T98 3030
#
#
# lower_bound 2250
# Training Accuracy: 0.6744186046511628
# T20 3150
# T137 2355
#
#
# lower_bound 2250
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_113/358329779.py in <module>
#       8         for i in random_draw:
#       9             if j % 2 == 1:
# ---> 10                 result = lda_complete_2(dftest[dftest.TRIP_ID == i]
#      11                                .reset_index().iloc[0]['TAXI_ID'],
#      12                                is_cut=True, cutoff=15*150, test_size=0.1) #cutoff=15*100, test_size=0.7)
#
# /tmp/ipykernel_113/3821474329.py in lda_complete_2(taxi_id, is_cut, cutoff, test_size)
#      47
#      48     # Fit the LDA model on the training data
# ---> 49     lda.fit(X_train, y_train)
#      50
#      51     # Predict the class labels for the test data
#
# /opt/conda/lib/python3.9/site-packages/sklearn/discriminant_analysis.py in fit(self, X, y)
#     551                         'is not supported '
#     552                         'with svd solver. Try another solver')
# --> 553             self._solve_svd(X, y)
#     554         elif self.solver == 'lsqr':
#     555             self._solve_lsqr(X, y, shrinkage=self.shrinkage,
#
# /opt/conda/lib/python3.9/site-packages/sklearn/discriminant_analysis.py in _solve_svd(self, X, y)
#     476         # Use SVD to find projection in the space spanned by the
#     477         # (n_classes) centers
# --> 478         _, S, Vt = linalg.svd(X, full_matrices=0)
#     479
#     480         self.explained_variance_ratio_ = (S**2 / np.sum(
#
# /opt/conda/lib/python3.9/site-packages/scipy/linalg/decomp_svd.py in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     121
#     122     # compute optimal lwork
# --> 123     lwork = _compute_lwork(gesXd_lwork, a1.shape[0], a1.shape[1],
#     124                            compute_uv=compute_uv, full_matrices=full_matrices)
#     125
#
# /opt/conda/lib/python3.9/site-packages/scipy/linalg/lapack.py in _compute_lwork(routine, *args, **kwargs)
#    1017     ret = routine(*args, **kwargs)
#    1018     if ret[-1] != 0:
# -> 1019         raise ValueError("Internal work array size computation failed: "
#    1020                          "%d" % (ret[-1],))
#    1021
#
# ValueError: Internal work array size computation failed: -10

# %% [markdown]
# good cutoff:
# - cutoff=15*100, test_size=0.7
# - better: - cutoff=15*150, test_size=0.1

# %% [markdown]
# ## Percentile Model

# %%
perc_model = []
for i in list(dftest['TAXI_ID']):
    tmp=dftrain[dftrain.TAXI_ID==i]['TRAVEL_TIME']
    p=(np.percentile(tmp,25)+np.percentile(tmp,50)+np.percentile(tmp,75)+np.percentile(tmp,99.5))/9
    perc_model.append(p)

# %%
random_idx = [26,14,1,284,107,131,40,79,32,176,69,281,139,137,233,83,143,279,46,
              316,287,268,302,165,54,311,244,68,251,89,262,194,39,255,239,59,9,
              156,293,285,180,164,263,294,118,100,8,110,224,84,245,87,171,149,199,
              292,207,188,272,170,190,71,36,124,290,4,132,257,191,74,280,50,288,225,223,206,269,184,
              17,138,158,53,34,13,210,128,90,214,159,278,246,20,116,73,299,126,275,15,109,315,301,312,253,265,29,
              157,97,252,66,101,163,127,249,148,161,240,82,154,65,95,282,56,230,319,142,47,88,10,111,86]

# %% [markdown]
# ## Final Result

# %%
for i in range(n):
    if i in random_idx:
        dcts[all_ids[i]] = perc_model[i]
    print(dcts[all_ids[i]])
# Out:
# 390
# 514.9666666666659
# 510
# 465
# 484.375
# 2625
# 300
# 450
# 446.6666666666667
# 574.9250000000037
# 620.1333333333301
# 315
# 360
# 1169.6666666666706
# 607.0666666666663
# 626.3166666666666
# 480
# 750.6833333333346
# 615
# 3150
# 462.4916666666665
# 435
# 240
# 450
# 405
# 390
# 508.3333333333333
# 570
# 645
# 526.1666666666671
# 525
# 420
# 474.93333333333186
# 0
# 681.266666666667
# 2325
# 928.2833333333336
# 510
# 390
# 545.0
# 490.71666666666636
# 270
# 165
# 555
# 465
# 0
# 465.3749999999991
# 551.6666666666666
# 660
# 570
# 656.200000000002
# 90
# 420
# 577.0333333333323
# 525.4999999999987
# 270
# 442.31666666666723
# 330
# 2325
# 625.6499999999999
# 570
# 240
# 180
# 285
# 240
# 649.7499999999991
# 497.93333333333067
# 210
# 576.0999999999967
# 464.08333333333303
# 2325
# 585.0
# 270
# 761.9833333333341
# 930.1916666666663
# 225
# 420
# 300
# 315
# 665.6166666666664
# 420
# 300
# 545.0
# 1020.6666666666614
# 460.71666666666636
# 360
# 667.1416666666679
# 554.6333333333329
# 491.96666666666636
# 514.1416666666661
# 466.6666666666667
# 555
# 585
# 375
# 2325
# 1663.166666666663
# 360
# 681.266666666667
# 255
# 300
# 676.6666666666666
# 582.4583333333331
# 540
# 465
# 180
# 345
# 660
# 1162.8416666666674
# 555
# 597.8583333333336
# 503.2000000000001
# 493.95833333333485
# 540
# 330
# 225
# 405
# 693.7500000000015
# 2745
# 458.3333333333333
# 300
# 555
# 375
# 495
# 240
# 461.55000000000047
# 2325
# 483.09999999999945
# 549.4666666666672
# 513.3333333333334
# 465
# 390
# 610.124999999999
# 446.6666666666667
# 255
# 300
# 510
# 660
# 517.5916666666664
# 585.0
# 556.5166666666664
# 435
# 450
# 618.4999999999976
# 3080.666666666677
# 255
# 345
# 330
# 300
# 508.96666666666687
# 643.6500000000009
# 360
# 510
# 555
# 495
# 475.2333333333324
# 330
# 537.9000000000027
# 517.5916666666664
# 849.4666666666672
# 562.374999999998
# 495
# 460.0
# 585
# 498.6666666666679
# 513.7166666666659
# 446.6666666666667
# 2325
# 360
# 555
# 465
# 656.3833333333332
# 660.4500000000015
# 360
# 2325
# 450
# 615
# 764.4000000000005
# 585
# 540
# 330
# 1020.6666666666614
# 450
# 465
# 570
# 466.72499999999974
# 675
# 420
# 405
# 579.8666666666668
# 2325
# 513.1166666666664
# 506.21666666666596
# 435
# 300
# 792.2666666666661
# 435
# 390
# 420
# 3255
# 576.6
# 2775
# 90
# 405
# 2325
# 360
# 555
# 521.1666666666664
# 445.0
# 405
# 2325
# 490.16666666666725
# 420
# 2460
# 330
# 656.200000000002
# 2325
# 2325
# 2265
# 360
# 360
# 2280
# 375
# 2325
# 687.4166666666694
# 463.15000000000055
# 376.6333333333326
# 675
# 330
# 420
# 450
# 602.4166666666679
# 510
# 615
# 497.6249999999997
# 525
# 420
# 300
# 555
# 600
# 510.27499999999924
# 473.63333333333384
# 450
# 315
# 390
# 446.6666666666667
# 761.9833333333341
# 545.0
# 480
# 525
# 517.4749999999995
# 255
# 617.1250000000009
# 828.6666666666664
# 508.68333333333186
# 330
# 579.8666666666668
# 330
# 508.3333333333333
# 315
# 15
# 390
# 300
# 525.5333333333328
# 753.7249999999949
# 345
# 483.3333333333333
# 345
# 180
# 485.8999999999999
# 700.3833333333326
# 330
# 345
# 487.70000000000135
# 270
# 465
# 482.6916666666663
# 390
# 240
# 470.2416666666674
# 472.8416666666665
# 551.0999999999998
# 422.20833333333303
# 446.6666666666667
# 0
# 462.4916666666665
# 532.1333333333345
# 480
# 764.4000000000005
# 490.73333333333335
# 390
# 508.96666666666687
# 360
# 546.1916666666533
# 1194.4583333333276
# 445.0
# 240
# 435
# 285
# 285
# 807.2833333333347
# 525
# 562.374999999998
# 521.758333333333
# 435
# 360
# 630
# 345
# 420
# 345
# 390
# 480
# 512.516666666667
# 493.3333333333333
# 2325
# 585
# 473.2833333333322
# 581.2750000000005
# 345
# 450
# 462.9166666666667

# %%
file1 = open("pred.csv", "w")
file1.write('"TRIP_ID","TRAVEL_TIME"\n')
for i in range(n):
    if i+1 != n:
        line = '"' + all_ids[i] + '",' + str(dcts[all_ids[i]]) + '\n'
    else:
        line = '"' + all_ids[i] + '",'  + str(dcts[all_ids[i]])
    file1.write(line)
file1.close()
